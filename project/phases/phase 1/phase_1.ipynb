# %%
#pip install pydealer

# %%
import pydealer
import random

# %%
deck = pydealer.Deck()
deck.shuffle()

user_hand = deck.deal(7)
agent_hand = deck.deal(7)

# converting the hand to a list of only ranks
user_hand_rank = []
agent_hand_rank = []


for i in user_hand:
  user_hand_rank.append(i.value)

for i in agent_hand:
  agent_hand_rank.append(i.value)

# %%
def call(isUser, hand, hand_rank ,isFirstRound, roundCardRank):

  # list of all possible ranks
  ranks = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']
  option = 0

  # if user is playing the first round
  if(isUser and isFirstRound):
    card_rank = input("\nEnter the rank of the card (caps): ")

    while card_rank not in ranks:
      print("\nWrong Card Rank")
      print("\nAvailable Ranks -> ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']")
      card_rank = input()

  # if agent is playing the first round - Honesty or Bluff
  elif(not isUser and isFirstRound):
    option = random.randint(0,1)

    # agent choses to be honest
    if option == 0:
      card_rank = max(hand_rank, key=hand_rank.count)

    # agent choses to bluff
    else:
      card_rank = random.choice(tuple(ranks))

  # if agent/user is playing the consecutive rounds
  else:
    card_rank = roundCardRank

  # if user is playing
  if(isUser):
    total_selected_cards = safe_int_input("\nEnter the total number to call: ")

    while total_selected_cards <= 0:
      print("\nNumber can't be less than 0")
      total_selected_cards = safe_int_input("\nEnter the total number to call: ")


    selected_cards_index = []
    selected_cards_name = []



    while len(selected_cards_name) != total_selected_cards:
      selected_index = safe_int_input("\nEnter the index of the cards you want to chose for the call: ")
      if(selected_index < 0 or selected_index >= len(hand) or selected_index in selected_cards_index):
        print("\nTry Again")
      else:
        selected_cards_index.append(selected_index)
        selected_cards_name.append(hand[selected_index])

    selected_cards_index.sort()

    for i in reversed(selected_cards_index):
        hand.get(i)
        hand_rank.pop(i)

    if(isFirstRound):
      print("\nUser called ",total_selected_cards, " of ", card_rank, "'s")
    else:
      print("\nUser added more ",total_selected_cards, " of ", card_rank, "'s")

  # if agent is playing - Honesty or Bluff
  else:
    print("\n-----------------------------Debug-----------------------------")
    print("Initial Option: ", option)
    print("-------------------------------Debug-----------------------------")

    # The agent chose to be honest but it does not have the current card so it shifts to bluffing
    if(option == 0 and not isFirstRound):
      if(hand_rank.count(card_rank) == 0):
        option = 1

    print("\n-----------------------------Debug-----------------------------")
    print("Final Option: ", option)
    print("-------------------------------Debug-----------------------------")


    # agent choses to be honest
    if(option == 0):
      total_selected_cards = hand_rank.count(card_rank)

      selected_cards_index = []
      selected_cards_name = []

      print("\n-----------------------------Debug-----------------------------")
      print("total selected cards: ", total_selected_cards)
      print("-------------------------------Debug-----------------------------")



      while len(selected_cards_name) != total_selected_cards:

        indices_to_remove = []

        for index, value in enumerate(hand):
          if value.value == card_rank:
            indices_to_remove.append(index)

        print("\n-----------------------------Debug Loop-----------------------------")
        for i in reversed(indices_to_remove):
          selected_cards_index.append(i)
          selected_cards_name.append(hand[i])

          print("\nIndex: ", i)

          print("\nAgent Hand\n")

          for index, value in enumerate(hand):
            print(index, " -> ", value)


          print("\nAgent Hand Rank: ", hand_rank)

          hand.get(i)
          hand_rank.pop(i)

        print("\nAgent Hand\n")

        for index, value in enumerate(hand):
          print(index, " -> ", value)


        print("\nAgent Hand Rank: ", hand_rank)
        print("-------------------------------Debug Loop-----------------------------")

        print("\n-----------------------------Debug-----------------------------")
        print("indices to remove: ", indices_to_remove)
        print("-------------------------------Debug-----------------------------")


    # agent choses to bluff
    else:
      total_selected_cards = random.randint(1, min(3, len(hand_rank)))

      print("\n-----------------------------Debug-----------------------------")
      print("total selected cards: ", total_selected_cards)
      print("-------------------------------Debug-----------------------------")

      selected_cards_index = []
      selected_cards_name = []

      while len(selected_cards_name) != total_selected_cards:

        selected_index = random.randint(0,len(hand)-1)
        if(selected_index in selected_cards_index or hand[selected_index].value == card_rank):
          continue
        else:
          selected_cards_index.append(selected_index)
          selected_cards_name.append(hand[selected_index])

      selected_cards_index.sort()

      print("\n-----------------------------Debug-----------------------------")
      print("selected cards index: ", selected_cards_index)
      print("-------------------------------Debug-----------------------------")

      print("\n-----------------------------Debug Loop-----------------------------")
      for i in reversed(selected_cards_index):
        print("\nIndex: ",i)
        print("\nAgent Hand\n")

        for index, value in enumerate(hand):
          print(index, " -> ", value)


        print("\nAgent Hand Rank: ", hand_rank)
        hand.get(i)
        hand_rank.pop(i)
      print("\nAgent Hand\n")

      for index, value in enumerate(hand):
        print(index, " -> ", value)


      print("\nAgent Hand Rank: ", hand_rank)
      print("\n-----------------------------Debug Loop-----------------------------")


    if(isFirstRound):
      print("\nAgent called ",total_selected_cards, " of ", card_rank, "'s")
    else:
      print("\nAgent added more ",total_selected_cards, " of ", card_rank, "'s")

  # the third argument is isFirstRound
  return selected_cards_name, card_rank, False

# %%
def safe_int_input(prompt):
  while True:
    try:
      return int(input(prompt))
    except ValueError:
      print("Invalid input. Please enter an integer.")

# %%
def printHand(hand):
  print("\nYour hand ( ", len(hand),  " cards ): \n")

  for index, value in enumerate(hand):
    print(index, " -> ", value)

# %%
print(random.choice([0,2]))
# Out:
# 2

# %%
def choice(isUser, resetRound, prevent_self_bluff):
  if(isUser):
    if(resetRound):
      option = 0
    elif(prevent_self_bluff):
      print("\nYou can chose either one of the following\n0 -> Continue Playing \n2 -> Pass")
      option = safe_int_input("\nEnter your choice: ")
      while(option < 0 or option > 2 or option == 1):
        print("\nWrong Choice")
        option = safe_int_input("Option: ")
    else:
      print("\nYou can chose either one of the following\n0 -> Continue Playing \n1 -> Call Bluff \n2 -> Pass")
      option = safe_int_input("\nEnter your choice: ")
      while(option < 0 or option > 2):
        print("\nWrong Choice")
        option = safe_int_input("Option: ")
  else:
    if(resetRound):
      option = 0
    elif(prevent_self_bluff):
      option = random.choice([0,2])
    else:
      option = random.randint(0,2)


  # the second argument is resetRound
  return option, False

# %%
def bluff(isUser, user_hand, agent_hand, user_hand_rank, agent_hand_rank, last_played_cards, card_rank, total_cards_round):

  isBluffing = False
  for i in last_played_cards:
    if(str(i.value) != card_rank):
      isBluffing = True
      break

  # If the user calls the bluff & it is a bluff
  if(isBluffing and isUser):
    agent_hand.insert_list(total_cards_round)

    for i in total_cards_round:
      agent_hand_rank.append(i.value)

  # If the user calls the bluff & it is not a bluff
  elif(not isBluffing and isUser):
    user_hand.insert_list(total_cards_round)

    for i in total_cards_round:
      user_hand_rank.append(i.value)

  # If the agent calls the bluff & it is a bluff
  elif(isBluffing and not isUser):
    user_hand.insert_list(total_cards_round)

    for i in total_cards_round:
      user_hand_rank.append(i.value)

  # If the agent calls the bluff & it is not a bluff
  elif(not isBluffing and not isUser):
    agent_hand.insert_list(total_cards_round)

    for i in total_cards_round:
      agent_hand_rank.append(i.value)

  return True if isBluffing else False

# %%
# User Starts First

printHand(user_hand)
isFirstRound = True;
selected_cards_name, card_rank, isFirstRound = call(True, user_hand, user_hand_rank, isFirstRound, "")
total_cards_round = selected_cards_name
last_played_cards = selected_cards_name
userPlaying = False
resetRound = False
roundCardRank = card_rank
pass_check = 2

# variable for making sure that agent does not call bluff on himself after the user choses to pass
prevent_self_bluff = False

while(len(user_hand) != 0 and len(agent_hand) != 0):

  # if users play pass consecutively then reset round
  if(pass_check == 0):

    resetRound = True
    isFirstRound = True

    # if(userPlaying):
    #   userPlaying = False

    total_cards_round = []
    pass_check = 2

  # if round resets
  if(resetRound):
    print("\nResetting Round")

  # if it is agents turn
  if(not userPlaying):
    option, resetRound = choice(False, resetRound, prevent_self_bluff)

    if(option == 0):
      print("\nAgent chose to continue playing")

      print("\n-----------------------------Debug-----------------------------")
      print("Agent Hand\n", agent_hand_rank)
      for index, value in enumerate(agent_hand):
        print(index, " -> ", value)
      print("------------------------------Debug-----------------------------")

      print("\n-----------------------------Debug-----------------------------")
      print("Agent Hand Rank: ", agent_hand_rank)
      print("-------------------------------Debug-----------------------------")

      selected_cards_name, card_rank, isFirstRound = call(False, agent_hand, agent_hand_rank ,isFirstRound, roundCardRank)

      print("\n-----------------------------Debug-----------------------------")
      print("Agent Called: ", selected_cards_name)
      print("-------------------------------Debug-----------------------------")

      roundCardRank = card_rank
      total_cards_round = total_cards_round + selected_cards_name
      last_played_cards = selected_cards_name
      userPlaying = True

      # we set it to false to reset it
      prevent_self_bluff = False

      # in order to implement pass check accurately
      pass_check = 2

    elif(option == 1):
      print("\nAgent chose to call bluff")
      bluffCaught = bluff(False, user_hand, agent_hand, user_hand_rank, agent_hand_rank, last_played_cards, card_rank, total_cards_round)
      if(bluffCaught):
        print("\nBluff was caught")
        userPlaying = False
      else:
        print("\nNo Bluff")
        userPlaying = True
      total_cards_round = []
      resetRound = True
      isFirstRound = True
      roundCardRank = ""
      last_played_cards = []

      # we set it to false to reset it
      prevent_self_bluff = False

      # in order to implement pass check accurately
      pass_check = 2

    elif(option == 2):
      print("\nAgent chose to pass")
      userPlaying = True
      pass_check -= 1
      last_played_cards = []

      # we set it to true to make sure that the agent/user cannot call bluff on himself
      prevent_self_bluff = True

    print("\nPile: ",len(total_cards_round), " & Agent Cards: ",len(agent_hand), " & User Cards: ",len(user_hand))

  # if it is users turn
  else:
    option, resetRound = choice(True, resetRound, prevent_self_bluff)
    if(option == 0):
      printHand(user_hand)
      selected_cards_name, card_rank, isFirstRound = call(True, user_hand, user_hand_rank ,isFirstRound, roundCardRank)
      print("\n-----------------------------Debug-----------------------------")
      print("User Called: ", selected_cards_name)
      print("-------------------------------Debug-----------------------------")
      roundCardRank = card_rank
      total_cards_round = total_cards_round + selected_cards_name
      last_played_cards = selected_cards_name
      userPlaying = False

      # we set it to false to reset it
      prevent_self_bluff = False

      # in order to implement pass check accurately
      pass_check = 2

    elif(option == 1):
      print("\nUser chose to call bluff")
      bluffCaught = bluff(True, user_hand, agent_hand, user_hand_rank, agent_hand_rank, selected_cards_name, card_rank, total_cards_round)
      if(bluffCaught):
        print("\nBluff was caught")
        userPlaying = True
      else:
        print("\nNo Bluff")
        userPlaying = False
      total_cards_round = []
      last_played_cards = []
      resetRound = True
      isFirstRound = True

      # we set it to false to reset it
      prevent_self_bluff = False

      # in order to implement pass check accurately
      pass_check = 2

    elif(option == 2):
      print("\nUser chose to pass")
      userPlaying = False
      pass_check -= 1
      last_played_cards = []

      # we set it to true to make sure that the agent/user cannot call bluff on himself
      prevent_self_bluff = True

    print("\nPile: ",len(total_cards_round), " & User Cards: ",len(user_hand), " & Agent Cards: ",len(agent_hand))

  if(len(user_hand) == 0):
    print("\nUser Won")
  elif(len(agent_hand) == 0):
    print("\nAgent Won")
# Out:
# Your hand (  7  cards ):
#
# 0  ->  5 of Clubs
# 1  ->  Ace of Spades
# 2  ->  Jack of Diamonds
# 3  ->  10 of Spades
# 4  ->  10 of Hearts
# 5  ->  2 of Clubs
# 6  ->  10 of Clubs
#
# Enter the rank of the card (caps): 10
#
# Enter the total number to call: 2
#
# Enter the index of the cards you want to chose for the call: 4
#
# Enter the index of the cards you want to chose for the call: 6
#
# User called  2  of  10 's
#
# Agent chose to continue playing
#
# -----------------------------Debug-----------------------------
# Agent Hand
#  ['4', 'Ace', 'Queen', 'Queen', '6', '2', '2']
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Clubs
# 3  ->  Queen of Diamonds
# 4  ->  6 of Spades
# 5  ->  2 of Spades
# 6  ->  2 of Hearts
# ------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Agent Hand Rank:  ['4', 'Ace', 'Queen', 'Queen', '6', '2', '2']
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Initial Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Final Option:  1
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# total selected cards:  2
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# selected cards index:  [2, 4]
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug Loop-----------------------------
#
# Index:  4
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Clubs
# 3  ->  Queen of Diamonds
# 4  ->  6 of Spades
# 5  ->  2 of Spades
# 6  ->  2 of Hearts
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', 'Queen', '6', '2', '2']
#
# Index:  2
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Clubs
# 3  ->  Queen of Diamonds
# 4  ->  2 of Spades
# 5  ->  2 of Hearts
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', 'Queen', '2', '2']
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2']
#
# -----------------------------Debug Loop-----------------------------
#
# Agent added more  2  of  10 's
#
# -----------------------------Debug-----------------------------
# Agent Called:  [Card(value='Queen', suit='Clubs'), Card(value='6', suit='Spades')]
# -------------------------------Debug-----------------------------
#
# Pile:  4  & Agent Cards:  5  & User Cards:  5
#
# You can chose either one of the following
# 0 -> Continue Playing
# 1 -> Call Bluff
# 2 -> Pass
#
# Enter your choice: 1
#
# User chose to call bluff
#
# Bluff was caught
#
# Pile:  0  & User Cards:  5  & Agent Cards:  9
#
# Resetting Round
#
# Your hand (  5  cards ):
#
# 0  ->  5 of Clubs
# 1  ->  Ace of Spades
# 2  ->  Jack of Diamonds
# 3  ->  10 of Spades
# 4  ->  2 of Clubs
#
# Enter the rank of the card (caps): Jack
#
# Enter the total number to call: 1
#
# Enter the index of the cards you want to chose for the call: 2
#
# User called  1  of  Jack 's
#
# -----------------------------Debug-----------------------------
# User Called:  [Card(value='Jack', suit='Diamonds')]
# -------------------------------Debug-----------------------------
#
# Pile:  1  & User Cards:  4  & Agent Cards:  9
#
# Agent chose to call bluff
#
# No Bluff
#
# Pile:  0  & Agent Cards:  10  & User Cards:  4
#
# Resetting Round
#
# Your hand (  4  cards ):
#
# 0  ->  5 of Clubs
# 1  ->  Ace of Spades
# 2  ->  10 of Spades
# 3  ->  2 of Clubs
#
# Enter the rank of the card (caps): 5
#
# Enter the total number to call: 1
#
# Enter the index of the cards you want to chose for the call: 0
#
# User called  1  of  5 's
#
# -----------------------------Debug-----------------------------
# User Called:  [Card(value='5', suit='Clubs')]
# -------------------------------Debug-----------------------------
#
# Pile:  1  & User Cards:  3  & Agent Cards:  10
#
# Agent chose to pass
#
# Pile:  1  & Agent Cards:  10  & User Cards:  3
#
# You can chose either one of the following
# 0 -> Continue Playing
# 2 -> Pass
#
# Enter your choice: 2
#
# User chose to pass
#
# Pile:  1  & User Cards:  3  & Agent Cards:  10
#
# Resetting Round
#
# Agent chose to continue playing
#
# -----------------------------Debug-----------------------------
# Agent Hand
#  ['4', 'Ace', 'Queen', '2', '2', '10', '10', 'Queen', '6', 'Jack']
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Hearts
# 6  ->  10 of Clubs
# 7  ->  Queen of Clubs
# 8  ->  6 of Spades
# 9  ->  Jack of Diamonds
# ------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10', '10', 'Queen', '6', 'Jack']
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Initial Option:  1
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Final Option:  1
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# total selected cards:  3
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# selected cards index:  [5, 7, 8]
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug Loop-----------------------------
#
# Index:  8
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Hearts
# 6  ->  10 of Clubs
# 7  ->  Queen of Clubs
# 8  ->  6 of Spades
# 9  ->  Jack of Diamonds
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10', '10', 'Queen', '6', 'Jack']
#
# Index:  7
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Hearts
# 6  ->  10 of Clubs
# 7  ->  Queen of Clubs
# 8  ->  Jack of Diamonds
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10', '10', 'Queen', 'Jack']
#
# Index:  5
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Hearts
# 6  ->  10 of Clubs
# 7  ->  Jack of Diamonds
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10', '10', 'Jack']
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Clubs
# 6  ->  Jack of Diamonds
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10', 'Jack']
#
# -----------------------------Debug Loop-----------------------------
#
# Agent called  3  of  Jack 's
#
# -----------------------------Debug-----------------------------
# Agent Called:  [Card(value='Queen', suit='Clubs'), Card(value='6', suit='Spades'), Card(value='10', suit='Hearts')]
# -------------------------------Debug-----------------------------
#
# Pile:  3  & Agent Cards:  7  & User Cards:  3
#
# You can chose either one of the following
# 0 -> Continue Playing
# 1 -> Call Bluff
# 2 -> Pass
#
# Enter your choice: 2
#
# User chose to pass
#
# Pile:  3  & User Cards:  3  & Agent Cards:  7
#
# Agent chose to continue playing
#
# -----------------------------Debug-----------------------------
# Agent Hand
#  ['4', 'Ace', 'Queen', '2', '2', '10', 'Jack']
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Clubs
# 6  ->  Jack of Diamonds
# ------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10', 'Jack']
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Initial Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Final Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# total selected cards:  1
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug Loop-----------------------------
#
# Index:  6
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Clubs
# 6  ->  Jack of Diamonds
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10', 'Jack']
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10']
# -------------------------------Debug Loop-----------------------------
#
# -----------------------------Debug-----------------------------
# indices to remove:  [6]
# -------------------------------Debug-----------------------------
#
# Agent added more  1  of  Jack 's
#
# -----------------------------Debug-----------------------------
# Agent Called:  [Card(value='Jack', suit='Diamonds')]
# -------------------------------Debug-----------------------------
#
# Pile:  4  & Agent Cards:  6  & User Cards:  3
#
# You can chose either one of the following
# 0 -> Continue Playing
# 1 -> Call Bluff
# 2 -> Pass
#
# Enter your choice: 2
#
# User chose to pass
#
# Pile:  4  & User Cards:  3  & Agent Cards:  6
#
# Agent chose to continue playing
#
# -----------------------------Debug-----------------------------
# Agent Hand
#  ['4', 'Ace', 'Queen', '2', '2', '10']
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Clubs
# ------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10']
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Initial Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Final Option:  1
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# total selected cards:  2
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# selected cards index:  [2, 3]
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug Loop-----------------------------
#
# Index:  3
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Spades
# 4  ->  2 of Hearts
# 5  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '2', '10']
#
# Index:  2
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  Queen of Diamonds
# 3  ->  2 of Hearts
# 4  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', 'Ace', 'Queen', '2', '10']
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  2 of Hearts
# 3  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', 'Ace', '2', '10']
#
# -----------------------------Debug Loop-----------------------------
#
# Agent added more  2  of  Jack 's
#
# -----------------------------Debug-----------------------------
# Agent Called:  [Card(value='Queen', suit='Diamonds'), Card(value='2', suit='Spades')]
# -------------------------------Debug-----------------------------
#
# Pile:  6  & Agent Cards:  4  & User Cards:  3
#
# You can chose either one of the following
# 0 -> Continue Playing
# 1 -> Call Bluff
# 2 -> Pass
#
# Enter your choice: 2
#
# User chose to pass
#
# Pile:  6  & User Cards:  3  & Agent Cards:  4
#
# Agent chose to continue playing
#
# -----------------------------Debug-----------------------------
# Agent Hand
#  ['4', 'Ace', '2', '10']
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  2 of Hearts
# 3  ->  10 of Clubs
# ------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Agent Hand Rank:  ['4', 'Ace', '2', '10']
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Initial Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Final Option:  1
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# total selected cards:  2
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# selected cards index:  [1, 3]
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug Loop-----------------------------
#
# Index:  3
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  2 of Hearts
# 3  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', 'Ace', '2', '10']
#
# Index:  1
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  Ace of Clubs
# 2  ->  2 of Hearts
#
# Agent Hand Rank:  ['4', 'Ace', '2']
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
#
# Agent Hand Rank:  ['4', '2']
#
# -----------------------------Debug Loop-----------------------------
#
# Agent added more  2  of  Jack 's
#
# -----------------------------Debug-----------------------------
# Agent Called:  [Card(value='Ace', suit='Clubs'), Card(value='10', suit='Clubs')]
# -------------------------------Debug-----------------------------
#
# Pile:  8  & Agent Cards:  2  & User Cards:  3
#
# You can chose either one of the following
# 0 -> Continue Playing
# 1 -> Call Bluff
# 2 -> Pass
#
# Enter your choice: 1
#
# User chose to call bluff
#
# Bluff was caught
#
# Pile:  0  & User Cards:  3  & Agent Cards:  10
#
# Resetting Round
#
# Your hand (  3  cards ):
#
# 0  ->  Ace of Spades
# 1  ->  10 of Spades
# 2  ->  2 of Clubs
#
# Enter the rank of the card (caps): Ace
#
# Enter the total number to call: 1
#
# Enter the index of the cards you want to chose for the call: 0
#
# User called  1  of  Ace 's
#
# -----------------------------Debug-----------------------------
# User Called:  [Card(value='Ace', suit='Spades')]
# -------------------------------Debug-----------------------------
#
# Pile:  1  & User Cards:  2  & Agent Cards:  10
#
# Agent chose to continue playing
#
# -----------------------------Debug-----------------------------
# Agent Hand
#  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2', 'Ace', '10']
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
# 2  ->  Queen of Clubs
# 3  ->  6 of Spades
# 4  ->  10 of Hearts
# 5  ->  Jack of Diamonds
# 6  ->  Queen of Diamonds
# 7  ->  2 of Spades
# 8  ->  Ace of Clubs
# 9  ->  10 of Clubs
# ------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Agent Hand Rank:  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2', 'Ace', '10']
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Initial Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Final Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# total selected cards:  1
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug Loop-----------------------------
#
# Index:  8
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
# 2  ->  Queen of Clubs
# 3  ->  6 of Spades
# 4  ->  10 of Hearts
# 5  ->  Jack of Diamonds
# 6  ->  Queen of Diamonds
# 7  ->  2 of Spades
# 8  ->  Ace of Clubs
# 9  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2', 'Ace', '10']
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
# 2  ->  Queen of Clubs
# 3  ->  6 of Spades
# 4  ->  10 of Hearts
# 5  ->  Jack of Diamonds
# 6  ->  Queen of Diamonds
# 7  ->  2 of Spades
# 8  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2', '10']
# -------------------------------Debug Loop-----------------------------
#
# -----------------------------Debug-----------------------------
# indices to remove:  [8]
# -------------------------------Debug-----------------------------
#
# Agent added more  1  of  Ace 's
#
# -----------------------------Debug-----------------------------
# Agent Called:  [Card(value='Ace', suit='Clubs')]
# -------------------------------Debug-----------------------------
#
# Pile:  2  & Agent Cards:  9  & User Cards:  2
#
# You can chose either one of the following
# 0 -> Continue Playing
# 1 -> Call Bluff
# 2 -> Pass
#
# Enter your choice: 2
#
# User chose to pass
#
# Pile:  2  & User Cards:  2  & Agent Cards:  9
#
# Agent chose to pass
#
# Pile:  2  & Agent Cards:  9  & User Cards:  2
#
# Resetting Round
#
# Your hand (  2  cards ):
#
# 0  ->  10 of Spades
# 1  ->  2 of Clubs
#
# Enter the rank of the card (caps): 10
#
# Enter the total number to call: 1
#
# Enter the index of the cards you want to chose for the call: 0
#
# User called  1  of  10 's
#
# -----------------------------Debug-----------------------------
# User Called:  [Card(value='10', suit='Spades')]
# -------------------------------Debug-----------------------------
#
# Pile:  1  & User Cards:  1  & Agent Cards:  9
#
# Agent chose to continue playing
#
# -----------------------------Debug-----------------------------
# Agent Hand
#  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2', '10']
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
# 2  ->  Queen of Clubs
# 3  ->  6 of Spades
# 4  ->  10 of Hearts
# 5  ->  Jack of Diamonds
# 6  ->  Queen of Diamonds
# 7  ->  2 of Spades
# 8  ->  10 of Clubs
# ------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Agent Hand Rank:  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2', '10']
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Initial Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# Final Option:  0
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug-----------------------------
# total selected cards:  2
# -------------------------------Debug-----------------------------
#
# -----------------------------Debug Loop-----------------------------
#
# Index:  8
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
# 2  ->  Queen of Clubs
# 3  ->  6 of Spades
# 4  ->  10 of Hearts
# 5  ->  Jack of Diamonds
# 6  ->  Queen of Diamonds
# 7  ->  2 of Spades
# 8  ->  10 of Clubs
#
# Agent Hand Rank:  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2', '10']
#
# Index:  4
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
# 2  ->  Queen of Clubs
# 3  ->  6 of Spades
# 4  ->  10 of Hearts
# 5  ->  Jack of Diamonds
# 6  ->  Queen of Diamonds
# 7  ->  2 of Spades
#
# Agent Hand Rank:  ['4', '2', 'Queen', '6', '10', 'Jack', 'Queen', '2']
#
# Agent Hand
#
# 0  ->  4 of Spades
# 1  ->  2 of Hearts
# 2  ->  Queen of Clubs
# 3  ->  6 of Spades
# 4  ->  Jack of Diamonds
# 5  ->  Queen of Diamonds
# 6  ->  2 of Spades
#
# Agent Hand Rank:  ['4', '2', 'Queen', '6', 'Jack', 'Queen', '2']
# -------------------------------Debug Loop-----------------------------
#
# -----------------------------Debug-----------------------------
# indices to remove:  [4, 8]
# -------------------------------Debug-----------------------------
#
# Agent added more  2  of  10 's
#
# -----------------------------Debug-----------------------------
# Agent Called:  [Card(value='10', suit='Clubs'), Card(value='10', suit='Hearts')]
# -------------------------------Debug-----------------------------
#
# Pile:  3  & Agent Cards:  7  & User Cards:  1
#
# You can chose either one of the following
# 0 -> Continue Playing
# 1 -> Call Bluff
# 2 -> Pass
#
# Enter your choice: 2
#
# User chose to pass
#
# Pile:  3  & User Cards:  1  & Agent Cards:  7
#
# Agent chose to pass
#
# Pile:  3  & Agent Cards:  7  & User Cards:  1
#
# Resetting Round
#
# Your hand (  1  cards ):
#
# 0  ->  2 of Clubs
#
# Enter the rank of the card (caps): 2
#
# Enter the total number to call: 1
#
# Enter the index of the cards you want to chose for the call: 0
#
# User called  1  of  2 's
#
# -----------------------------Debug-----------------------------
# User Called:  [Card(value='2', suit='Clubs')]
# -------------------------------Debug-----------------------------
#
# Pile:  1  & User Cards:  0  & Agent Cards:  7
#
# User Won
